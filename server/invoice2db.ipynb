# %%
from PIL import Image
import os

folder_path = '/home/manasa/Desktop/Code/hackathon/pdf_images'

# List all PNG files in the folder
image_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

print(image_paths)

images = [Image.open(path) for path in image_paths]
# Out:
# ['/home/manasa/Desktop/Code/hackathon/pdf_images/254_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/299_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/429_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/676_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/1059_page_2.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/1059_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/450_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/232_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/261_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/421_page_1.png']

# %%
import google.generativeai as genai
import os


os.environ['GOOGLE_API_KEY'] = 'AIzaSyDM2ks9JroT_5fG2WD4tfkHX6bzejhTKqo'
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

model = genai.GenerativeModel('gemini-1.5-flash')
# Folder where images are stored
image = Image.open("/home/manasa/Desktop/Code/hackathon/pdf_images/1059_page_1.png")
prompt = """
Analyze these grocery bill invoices. For each edible product listed, provide a comprehensive nutritional and environmental assessment based on the estimated quantity purchased. Use the following format for each product:

{
    "product_name": "",
    "price_paid": 0,
    "num_items": 0,
    "estimated_quantity": {"value": 0, "unit": ""},
    "serving_size": "",
    "energy": {
        "per_serving": {"value": 0, "unit": "kcal"}
    },
    "macronutrients": {
        "total_fat": {"per_serving": {"value": 0, "unit": "g"}},
        "carbohydrates": {"per_serving": {"value": 0, "unit": "g"}},
        "protein": {"per_serving": {"value": 0, "unit": "g"}}
    },
    "micronutrients": {
        "sodium": {"per_serving": {"value": 0, "unit": "mg"}},
        "key_vitamins_minerals": [
            {"name": "", "value": 0, "unit": ""}
        ]
    },
    "fiber": {
        "total": {"per_serving": {"value": 0, "unit": "g"}},
        "soluble": {"per_serving": {"value": 0, "unit": "g"}},
        "insoluble": {"per_serving": {"value": 0, "unit": "g"}}
    },
    "allergens": [],
    "nutrient_density_score": 0,
    "glycemic_index": 0,
    "glycemic_load": 0,
    "protein_quality": {
        "score": 0,
        "method": "PDCAAS/DIAAS"
    },
    "phytonutrients": [
        {"name": "", "presence": "high/medium/low"}
    ],
    "micronutrient_density": {
        "per_100_calories": [
            {"nutrient": "", "value": 0, "unit": ""}
        ],
        "per_100_grams": [
            {"nutrient": "", "value": 0, "unit": ""}
        ]
    },
    "satiety_index": 0,
    "environmental_impact": {
        "water_usage": {"value": 0, "unit": "L/kg"},
        "carbon_footprint": {"value": 0, "unit": "kg CO2e/kg"},
        "land_use": {"value": 0, "unit": "m²/kg"}
    },
    "versatility_score": 0,
    "cost_nutrient_ratio": 0,
    "nutritional_summary": ""
}

Estimate the quantity based on the price paid and typical market prices. Provide rough estimates for nutritional content and environmental impact based on this estimated quantity. If certain information is not applicable or available, you may omit those fields. Focus on providing a general nutritional and environmental overview rather than precise values.

For each metric:
1. Nutrient Density Score: Calculate based on vitamin, mineral, fiber, and protein content relative to calorie content.
2. Glycemic Index and Load: Assess these values, noting that foods like lentils and pulses typically have low values.
3. Protein Quality: Evaluate using PDCAAS or DIAAS metrics where possible.
4. Fiber Content: Analyze both quantity and type (soluble vs. insoluble).
5. Phytonutrient Profile: Assess the presence of beneficial compounds like polyphenols, flavonoids, and antioxidants.
6. Micronutrient Density: Compare vitamin and mineral content per 100 calories and per 100 grams.
7. Satiety Index: Provide an estimate of how filling the food is relative to its calorie content.
8. Environmental Impact: Include metrics on water usage, carbon footprint, and land use for production.
9. Versatility Score: Develop a score based on the food's adaptability to various dishes and cuisines.
10. Cost-Nutrient Ratio: Calculate the nutritional value provided per unit of cost.

List all edible products from the invoices in this format, highlighting the nutritional benefits of foods like lentils, pulses, and other nutrient-dense options.
"""

# Generate content with multiple images
response = model.generate_content([prompt, image])

print(response.text)
# Out:
# ```json
# [
#     {
#         "product_name": "Too Yumm - Naagin Sauce - Smoking Hot Bhoot Chips",
#         "price_paid": 19.00,
#         "num_items": 1,
#         "estimated_quantity": {
#             "value": 1,
#             "unit": "packet"
#         },
#         "serving_size": "As per package instructions",
#         "energy": {
#             "per_serving": {
#                 "value": null,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": []
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [
#             "Soy",
#             "Wheat",
#             "Gluten",
#             "Milk",
#             "Peanuts",
#             "Tree Nuts",
#             "Mustard",
#             "Sesame Seeds"
#         ],
#         "nutrient_density_score": null,
#         "glycemic_index": null,
#         "glycemic_load": null,
#         "protein_quality": {
#             "score": null,
#             "method": null
#         },
#         "phytonutrients": [],
#         "micronutrient_density": {
#             "per_100_calories": [],
#             "per_100_grams": []
#         },
#         "satiety_index": null,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": null,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": null,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": null,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": null,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "This snack is high in calories and may contain allergens like soy, wheat, gluten, milk, peanuts, tree nuts, mustard, and sesame seeds."
#     },
#     {
#         "product_name": "All Out Ultra Mosquito Repellent Liquid Vaporizer Machine 2 Refills",
#         "price_paid": 160.20,
#         "num_items": 1,
#         "estimated_quantity": {
#             "value": 2,
#             "unit": "refills"
#         },
#         "serving_size": null,
#         "energy": {
#             "per_serving": {
#                 "value": null,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": []
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [],
#         "nutrient_density_score": null,
#         "glycemic_index": null,
#         "glycemic_load": null,
#         "protein_quality": {
#             "score": null,
#             "method": null
#         },
#         "phytonutrients": [],
#         "micronutrient_density": {
#             "per_100_calories": [],
#             "per_100_grams": []
#         },
#         "satiety_index": null,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": null,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": null,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": null,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": null,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "This product is not edible."
#     },
#     {
#         "product_name": "Town Grocer Kashmiri Rajma",
#         "price_paid": 105.00,
#         "num_items": 1,
#         "estimated_quantity": {
#             "value": 500,
#             "unit": "g"
#         },
#         "serving_size": "1/2 cup cooked",
#         "energy": {
#             "per_serving": {
#                 "value": null,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": [
#                 {
#                     "name": "Iron",
#                     "value": null,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Fiber",
#                     "value": null,
#                     "unit": "g"
#                 },
#                 {
#                     "name": "Folate",
#                     "value": null,
#                     "unit": "mcg"
#                 },
#                 {
#                     "name": "Magnesium",
#                     "value": null,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Potassium",
#                     "value": null,
#                     "unit": "mg"
#                 }
#             ]
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [],
#         "nutrient_density_score": null,
#         "glycemic_index": null,
#         "glycemic_load": null,
#         "protein_quality": {
#             "score": null,
#             "method": null
#         },
#         "phytonutrients": [
#             {
#                 "name": "Polyphenols",
#                 "presence": "medium"
#             },
#             {
#                 "name": "Antioxidants",
#                 "presence": "medium"
#             }
#         ],
#         "micronutrient_density": {
#             "per_100_calories": [],
#             "per_100_grams": []
#         },
#         "satiety_index": null,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": null,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": null,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": null,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": null,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "Rajma, or kidney beans, are a great source of protein, fiber, iron, folate, magnesium, and potassium. They have a low glycemic index and load, making them a healthy choice for blood sugar control. They are also rich in antioxidants and polyphenols, which offer various health benefits."
#     },
#     {
#         "product_name": "Skippi Ice Pops Natural 3 Flavours Pink Guava Pineapple Lemon Carton",
#         "price_paid": 114.00,
#         "num_items": 1,
#         "estimated_quantity": {
#             "value": 1,
#             "unit": "carton"
#         },
#         "serving_size": "As per package instructions",
#         "energy": {
#             "per_serving": {
#                 "value": null,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": []
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [],
#         "nutrient_density_score": null,
#         "glycemic_index": null,
#         "glycemic_load": null,
#         "protein_quality": {
#             "score": null,
#             "method": null
#         },
#         "phytonutrients": [],
#         "micronutrient_density": {
#             "per_100_calories": [],
#             "per_100_grams": []
#         },
#         "satiety_index": null,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": null,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": null,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": null,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": null,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "This product is a processed food item and may be high in sugar and calories."
#     },
#     {
#         "product_name": "Dr Good Eggs Premium Fresh 6 Pc [Part Of Combo]",
#         "price_paid": 97.00,
#         "num_items": 2,
#         "estimated_quantity": {
#             "value": 12,
#             "unit": "pcs"
#         },
#         "serving_size": "1 egg",
#         "energy": {
#             "per_serving": {
#                 "value": 78,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": 5.3,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": 0.6,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": 6.3,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": 62,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": [
#                 {
#                     "name": "Vitamin A",
#                     "value": 100,
#                     "unit": "IU"
#                 },
#                 {
#                     "name": "Vitamin B12",
#                     "value": 0.6,
#                     "unit": "mcg"
#                 },
#                 {
#                     "name": "Vitamin D",
#                     "value": 44,
#                     "unit": "IU"
#                 },
#                 {
#                     "name": "Choline",
#                     "value": 147,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Iron",
#                     "value": 1,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Calcium",
#                     "value": 30,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Phosphorus",
#                     "value": 95,
#                     "unit": "mg"
#                 }
#             ]
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": 0,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": 0,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": 0,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [],
#         "nutrient_density_score": null,
#         "glycemic_index": null,
#         "glycemic_load": null,
#         "protein_quality": {
#             "score": 100,
#             "method": "PDCAAS"
#         },
#         "phytonutrients": [
#             {
#                 "name": "Choline",
#                 "presence": "high"
#             }
#         ],
#         "micronutrient_density": {
#             "per_100_calories": [
#                 {
#                     "nutrient": "Vitamin B12",
#                     "value": 0.77,
#                     "unit": "mcg"
#                 },
#                 {
#                     "nutrient": "Choline",
#                     "value": 188,
#                     "unit": "mg"
#                 }
#             ],
#             "per_100_grams": [
#                 {
#                     "nutrient": "Vitamin B12",
#                     "value": 0.97,
#                     "unit": "mcg"
#                 },
#                 {
#                     "nutrient": "Choline",
#                     "value": 188,
#                     "unit": "mg"
#                 }
#             ]
#         },
#         "satiety_index": 150,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": 150,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": 4.5,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": 1.3,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": 10,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "Eggs are a great source of high-quality protein, choline, and various essential vitamins and minerals. They are versatile and can be enjoyed in many ways. However, it is important to consider the environmental impact of egg production, including water usage, carbon footprint, and land use."
#     },
#     {
#         "product_name": "Robusta Banana (Arati Pandlu) [Part Of Combo]",
#         "price_paid": 61.01,
#         "num_items": 2,
#         "estimated_quantity": {
#             "value": 2,
#             "unit": "kg"
#         },
#         "serving_size": "1 medium banana",
#         "energy": {
#             "per_serving": {
#                 "value": 105,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": 0.3,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": 27,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": 1.1,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": 1,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": [
#                 {
#                     "name": "Vitamin B6",
#                     "value": 0.4,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Vitamin C",
#                     "value": 10,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Potassium",
#                     "value": 422,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Manganese",
#                     "value": 0.3,
#                     "unit": "mg"
#                 }
#             ]
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": 3.1,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": 1.5,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": 1.6,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [],
#         "nutrient_density_score": null,
#         "glycemic_index": 50,
#         "glycemic_load": 13.5,
#         "protein_quality": {
#             "score": null,
#             "method": null
#         },
#         "phytonutrients": [
#             {
#                 "name": "Antioxidants",
#                 "presence": "high"
#             },
#             {
#                 "name": "Polyphenols",
#                 "presence": "medium"
#             }
#         ],
#         "micronutrient_density": {
#             "per_100_calories": [
#                 {
#                     "nutrient": "Vitamin B6",
#                     "value": 0.38,
#                     "unit": "mg"
#                 },
#                 {
#                     "nutrient": "Vitamin C",
#                     "value": 9.5,
#                     "unit": "mg"
#                 },
#                 {
#                     "nutrient": "Potassium",
#                     "value": 402,
#                     "unit": "mg"
#                 }
#             ],
#             "per_100_grams": [
#                 {
#                     "nutrient": "Vitamin B6",
#                     "value": 0.37,
#                     "unit": "mg"
#                 },
#                 {
#                     "nutrient": "Vitamin C",
#                     "value": 8.9,
#                     "unit": "mg"
#                 },
#                 {
#                     "nutrient": "Potassium",
#                     "value": 398,
#                     "unit": "mg"
#                 }
#             ]
#         },
#         "satiety_index": 60,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": 74,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": 0.4,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": 0.4,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": 8,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "Bananas are a good source of potassium, fiber, and vitamin B6. They are also rich in antioxidants and have a low glycemic index, making them a healthy choice for blood sugar control. However, banana production can have a significant environmental impact, particularly in terms of water usage and land use."
#     },
#     {
#         "product_name": "Basic Kala Chana",
#         "price_paid": 89.00,
#         "num_items": 1,
#         "estimated_quantity": {
#             "value": 500,
#             "unit": "g"
#         },
#         "serving_size": "1/2 cup cooked",
#         "energy": {
#             "per_serving": {
#                 "value": null,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": [
#                 {
#                     "name": "Iron",
#                     "value": null,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Fiber",
#                     "value": null,
#                     "unit": "g"
#                 },
#                 {
#                     "name": "Folate",
#                     "value": null,
#                     "unit": "mcg"
#                 },
#                 {
#                     "name": "Magnesium",
#                     "value": null,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Potassium",
#                     "value": null,
#                     "unit": "mg"
#                 }
#             ]
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [],
#         "nutrient_density_score": null,
#         "glycemic_index": null,
#         "glycemic_load": null,
#         "protein_quality": {
#             "score": null,
#             "method": null
#         },
#         "phytonutrients": [
#             {
#                 "name": "Polyphenols",
#                 "presence": "medium"
#             },
#             {
#                 "name": "Antioxidants",
#                 "presence": "medium"
#             }
#         ],
#         "micronutrient_density": {
#             "per_100_calories": [],
#             "per_100_grams": []
#         },
#         "satiety_index": null,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": null,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": null,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": null,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": null,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "Kala chana, or black chickpeas, are a nutrient-rich legume packed with protein, fiber, iron, folate, magnesium, and potassium. They have a low glycemic index and load, making them a healthy choice for blood sugar control. They are also rich in antioxidants and polyphenols, offering various health benefits."
#     },
#     {
#         "product_name": "Kitchen Gems Rajma Standard",
#         "price_paid": 159.00,
#         "num_items": 1,
#         "estimated_quantity": {
#             "value": 500,
#             "unit": "g"
#         },
#         "serving_size": "1/2 cup cooked",
#         "energy": {
#             "per_serving": {
#                 "value": null,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "micronutrients": {
#             "sodium": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "mg"
#                 }
#             },
#             "key_vitamins_minerals": [
#                 {
#                     "name": "Iron",
#                     "value": null,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Fiber",
#                     "value": null,
#                     "unit": "g"
#                 },
#                 {
#                     "name": "Folate",
#                     "value": null,
#                     "unit": "mcg"
#                 },
#                 {
#                     "name": "Magnesium",
#                     "value": null,
#                     "unit": "mg"
#                 },
#                 {
#                     "name": "Potassium",
#                     "value": null,
#                     "unit": "mg"
#                 }
#             ]
#         },
#         "fiber": {
#             "total": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "soluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             },
#             "insoluble": {
#                 "per_serving": {
#                     "value": null,
#                     "unit": "g"
#                 }
#             }
#         },
#         "allergens": [],
#         "nutrient_density_score": null,
#         "glycemic_index": null,
#         "glycemic_load": null,
#         "protein_quality": {
#             "score": null,
#             "method": null
#         },
#         "phytonutrients": [
#             {
#                 "name": "Polyphenols",
#                 "presence": "medium"
#             },
#             {
#                 "name": "Antioxidants",
#                 "presence": "medium"
#             }
#         ],
#         "micronutrient_density": {
#             "per_100_calories": [],
#             "per_100_grams": []
#         },
#         "satiety_index": null,
#         "environmental_impact": {
#             "water_usage": {
#                 "value": null,
#                 "unit": "L/kg"
#             },
#             "carbon_footprint": {
#                 "value": null,
#                 "unit": "kg CO2e/kg"
#             },
#             "land_use": {
#                 "value": null,
#                 "unit": "m²/kg"
#             }
#         },
#         "versatility_score": null,
#         "cost_nutrient_ratio": null,
#         "nutritional_summary": "Rajma, or kidney beans, are a great source of protein, fiber, iron, folate, magnesium, and potassium. They have a low glycemic index and load, making them a healthy choice for blood sugar control. They are also rich in antioxidants and polyphenols, offering various health benefits."
#     }
# ]
# ```

# %% [markdown]
# gemini pro

# %%
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "```json\n{\n    \"Doritos Dinamita Sizzling Hot\": {\n        \"product_name\": \"Doritos Dinamita Sizzling Hot\",\n        \"price_paid\": 25.5,\n        \"num_items\": 1,\n        \"estimated_quantity\": {\n            \"value\": 1,\n            \"unit\": \"pack\"\n        },\n        \"serving_size\": \"1 serving = 30g\",\n        \"energy\": {\n            \"total\": {\n                \"value\": 150,\n                \"unit\": \"kcal\"\n            },\n            \"per_serving\": {\n                \"value\": 150,\n                \"unit\": \"kcal\"\n            }\n        },\n        \"macronutrients\": {\n            \"total_fat\": {\n                \"total\": {\n                    \"value\": 9,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 9,\n                    \"unit\": \"g\"\n                }\n            },\n            \"saturated_fat\": {\n                \"total\": {\n                    \"value\": 1.5,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 1.5,\n                    \"unit\": \"g\"\n                }\n            },\n            \"trans_fat\": {\n                \"total\": {\n                    \"value\": 0,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 0,\n                    \"unit\": \"g\"\n                }\n            },\n            \"cholesterol\": {\n                \"total\": {\n                    \"value\": 0,\n                    \"unit\": \"mg\"\n                },\n                \"per_serving\": {\n                    \"value\": 0,\n                    \"unit\": \"mg\"\n                }\n            },\n            \"total_carbohydrates\": {\n                \"total\": {\n                    \"value\": 18,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 18,\n                    \"unit\": \"g\"\n                }\n            },\n            \"sugars\": {\n                \"total\": {\n                    \"value\": 1,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 1,\n                    \"unit\": \"g\"\n                }\n            },\n            \"added_sugars\": {\n                \"total\": {\n                    \"value\": 1,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 1,\n                    \"unit\": \"g\"\n                }\n            },\n            \"dietary_fiber\": {\n                \"total\": {\n                    \"value\": 1,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 1,\n                    \"unit\": \"g\"\n                }\n            },\n            \"protein\": {\n                \"total\": {\n                    \"value\": 2,\n                    \"unit\": \"g\"\n                },\n                \"per_serving\": {\n                    \"value\": 2,\n                    \"unit\": \"g\"\n                }\n            }\n        },\n        \"micronutrients\": {\n            \"sodium\": {\n                \"total\": {\n                    \"value\": 170,\n                    \"unit\": \"mg\"\n                },\n                \"per_serving\": {\n                    \"value\": 170,\n                    \"unit\": \"mg\"\n                }\n            },\n            \"vitamins_minerals\": [\n                {\n                    \"name\": \"Vitamin A\",\n                    \"total\": {\n                        \"value\": 2,\n                        \"unit\": \"%DV\"\n                    },\n                    \"per_serving\": {\n                        \"value\": 2,\n            ...
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0,
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HATE_SPEECH",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HARASSMENT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#               "probability": "NEGLIGIBLE"
#             }
#           ],
#           "citation_metadata": {
#             "citation_sources": [
#               {
#                 "start_index": 21646,
#                 "end_index": 21774,
#                 "uri": "https://cappuccinooracle.com/rooibos-vs-honeybush-whats-the-difference/",
#                 "license_": ""
#               }
#             ]
#           }
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 1323,
#         "candidates_token_count": 8192,
#         "total_token_count": 9515
#       }
#     }),
# )

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db

# Assuming 'response' is the Gemini API response object
gemini_output = response.text  # or response.content, depending on the exact structure

# Format data for Firebase
firebase_data = {
    "products": gemini_output
}

# Initialize Firebase app
cred = credentials.Certificate("/home/manasa/Desktop/Code/hackathon/consciouscart-16d52-firebase-adminsdk-760qa-40f97a51ac.json")
firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://consciouscart-16d52-default-rtdb.firebaseio.com/'
})

# Get a reference to the database
ref = db.reference('/')

# Upload the data to Firebase
ref.set(firebase_data)

print("Data successfully uploaded to Firebase!")
# Out:
# Data successfully uploaded to Firebase!
